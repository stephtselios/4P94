# %% [markdown]
# # Homework
#
# * Create derived statistic for slap and backhand shots
# * Note, the analysis can be extended beyond the wrist shot model example
# * Assess and report the derived statistics across relevant factors

# %%
# %matplotlib inline
import os
import sys
import numpy 
import pandas 
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

# !pip install plotly

# imports regression library
# OLS: ordinary least squares (estimation technique used to estimate the linear regression model)
import statsmodels.api as sm
from statsmodels.formula.api import ols
    
# Set some Pandas options
pandas.set_option('display.notebook_repr_html', True)
pandas.set_option('display.max_columns', 20)
pandas.set_option('display.max_rows', 50)

from decimal import getcontext, Decimal
# Set the precision.
getcontext().prec = 2

# %%
dm = dm[(dm['advantagetypeshooter']=='EV')] 
dm = dm[dm['zone']=="O"]

# %%
dm.head(2)
# Out:
#    season  gamenumber   gamedate vteamcode hteamcode  eventnumber  period  \
# 0    2011       20001  10/6/2011       PHI       BOS            4       1
# 1    2011       20001  10/6/2011       PHI       BOS            9       1
#
#    eventtimefromzero advantagetypeshooter advantagetypegoalie   ...     \
# 0                 47                   EV                  EV   ...
# 1                114                   EV                  EV   ...
#
#   position      namegoalie  tgoals ogoals  zone   X   Y  XNorm  YNorm shotType
# 0        G  BRYZGALOV_ILYA       0      0     O  32 -14     32    -14     Snap
# 1        G  BRYZGALOV_ILYA       0      0     O  37 -18     37    -18     Snap
#
# [2 rows x 25 columns]

# %%
dm.describe()
# Out:
#         season    gamenumber   eventnumber        period  eventtimefromzero  \
# count  57186.0  57186.000000  57186.000000  57186.000000        57186.00000
# mean    2011.0  20621.982094    154.552303      2.034432          584.16901
# std        0.0    354.047357     89.652301      0.850648          346.91897
# min     2011.0  20001.000000      3.000000      1.000000            4.00000
# 25%     2011.0  20318.000000     77.000000      1.000000          277.00000
# 50%     2011.0  20625.000000    154.000000      2.000000          573.00000
# 75%     2011.0  20928.000000    229.000000      3.000000          885.00000
# max     2011.0  21230.000000    392.000000      4.000000         1200.00000
#
#             isTHome  playernumber        tgoals        ogoals             X  \
# count  57186.000000  57186.000000  57186.000000  57186.000000  57186.000000
# mean       0.485433     29.926486      1.304480      1.180569      0.264016
# std        0.499792     13.608431      1.364192      1.280953     64.288069
# min        0.000000      1.000000      0.000000      0.000000    -99.000000
# 25%        0.000000     30.000000      0.000000      0.000000    -64.000000
# 50%        0.000000     31.000000      1.000000      1.000000     28.000000
# 75%        1.000000     35.000000      2.000000      2.000000     64.000000
# max        1.000000     70.000000      9.000000      9.000000     97.000000
#
#                   Y         XNorm         YNorm
# count  57186.000000  57186.000000  57186.000000
# mean      -0.178663     62.067604     -0.376613
# std       19.317856     16.750245     19.315011
# min      -42.000000     26.000000    -42.000000
# 25%      -15.000000     49.000000    -15.000000
# 50%        0.000000     64.000000     -1.000000
# 75%       14.000000     77.000000     14.000000
# max       42.000000     99.000000     42.000000

# %%
dm.groupby(['eventtype'])[['XNorm', 'YNorm']].describe()
# Out:
#                         XNorm         YNorm
# eventtype
# GOAL      count   4678.000000   4678.000000
#           mean      70.962591     -0.132535
#           std       13.088705     12.242820
#           min       27.000000    -39.000000
#           25%       64.000000     -6.000000
#           50%       75.000000      0.000000
#           75%       81.000000      6.000000
#           max       97.000000     40.000000
# SHOT      count  52508.000000  52508.000000
#           mean      61.275139     -0.398358
#           std       16.811628     19.822985
#           min       26.000000    -42.000000
#           25%       48.000000    -16.000000
#           50%       63.000000     -1.000000
#           75%       77.000000     15.000000
#           max       99.000000     42.000000

# %%
pandas.crosstab(dm['shotType'], dm['eventtype'], margins = True)
# Out:
# eventtype    GOAL   SHOT    All
# shotType
# Backhand      513   4709   5222
# Deflected     172    701    873
# Slap          545  10716  11261
# Snap          681   7574   8255
# Tip-In        432   1927   2359
# Wrap-around    49    897    946
# Wrist        2286  25984  28270
# All          4678  52508  57186

# %%
dm['isgoal'] = dm['eventtype']=='GOAL'
dm['XNormAdj'] = 99 - dm['XNorm']
dm.groupby(['eventtype'])[['XNormAdj', 'YNorm']].describe()
# Out:
#                      XNormAdj         YNorm
# eventtype
# GOAL      count   4678.000000   4678.000000
#           mean      28.037409     -0.132535
#           std       13.088705     12.242820
#           min        2.000000    -39.000000
#           25%       18.000000     -6.000000
#           50%       24.000000      0.000000
#           75%       35.000000      6.000000
#           max       72.000000     40.000000
# SHOT      count  52508.000000  52508.000000
#           mean      37.724861     -0.398358
#           std       16.811628     19.822985
#           min        0.000000    -42.000000
#           25%       22.000000    -16.000000
#           50%       36.000000     -1.000000
#           75%       51.000000     15.000000
#           max       73.000000     42.000000

# %%
dm['XNormAdj'] = dm['XNormAdj'] + 1
dm['YNormAdj'] = numpy.absolute(dm['YNorm'])
dm['YNormAdj'] = dm['YNormAdj'] + 1

dm['lnX'] = numpy.log(dm['XNormAdj'])
dm['lnY'] = numpy.log(dm['YNormAdj'])

dm['dscore'] = dm['tgoals'] - dm['ogoals']
dm['oteamcode'] = dm.apply(lambda x: 1 if (x['teamcode'] == x['hteamcode']) else x['vteamcode'], axis=1)

# %%
dw = dm[dm['shotType']=='Backhand']

# %%
dg = dw[dw['eventtype']=='GOAL']

plt.hist2d(dg['XNormAdj'], dg['YNorm'],bins=30)
plt.show()

# %%
m1 = sm.Logit(dw['isgoal'], sm.add_constant(dw['lnX'])).fit()
print (m1.get_margeff(method='dydx', at='overall').summary())

# Generate predicted values and predict results
dw.ix[:, 'pgoalx'] = m1.predict()
dw.plot(kind='scatter',x='XNormAdj', y='pgoalx')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.317752
#          Iterations 7
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# lnX           -0.0770      0.013     -5.844      0.000        -0.103    -0.051
# ==============================================================================
# C:\Programs\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_margins.py:522: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   exog_names.pop(const_idx)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
m2 = sm.Logit(dw['isgoal'], sm.add_constant(dw['lnY'])).fit()
print (m2.get_margeff(method='dydx', at='overall').summary())
# Generate predicted values and predict results
dw.ix[:, 'pgoaly'] = m2.predict()
dw.plot(kind='scatter', x='YNormAdj', y='pgoaly')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.301774
#          Iterations 7
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# lnY           -0.0652      0.005    -13.630      0.000        -0.075    -0.056
# ==============================================================================
# C:\Programs\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_margins.py:522: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   exog_names.pop(const_idx)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
m3 = sm.Logit(dw['isgoal'], sm.add_constant(dw[['lnX', 'lnY']])).fit()
print (m3.get_margeff(method='dydx', at='overall').summary())
dw.ix[:, 'pgoal'] = m3.predict()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.297700
#          Iterations 7
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# lnX           -0.0902      0.014     -6.341      0.000        -0.118    -0.062
# lnY           -0.0683      0.005    -13.777      0.000        -0.078    -0.059
# ==============================================================================
# C:\Programs\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_margins.py:522: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   exog_names.pop(const_idx)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
dw.describe()
# Out:
#        season    gamenumber  eventnumber       period  eventtimefromzero  \
# count  5222.0   5222.000000  5222.000000  5222.000000        5222.000000
# mean   2011.0  20622.310417   155.463807     2.038491         587.949828
# std       0.0    350.455459    90.302794     0.852822         347.328575
# min    2011.0  20001.000000     3.000000     1.000000           5.000000
# 25%    2011.0  20323.000000    77.000000     1.000000         276.250000
# 50%    2011.0  20623.000000   156.000000     2.000000         577.500000
# 75%    2011.0  20923.000000   230.000000     3.000000         894.750000
# max    2011.0  21230.000000   389.000000     4.000000        1200.000000
#
#            isTHome  playernumber       tgoals       ogoals            X  \
# count  5222.000000   5222.000000  5222.000000  5222.000000  5222.000000
# mean      0.479127     29.869590     1.316162     1.195136    -0.116047
# std       0.499612     13.707482     1.362129     1.287614    77.157743
# min       0.000000      1.000000     0.000000     0.000000   -97.000000
# 25%       0.000000     30.000000     0.000000     0.000000   -79.000000
# 50%       0.000000     31.000000     1.000000     1.000000   -37.500000
# 75%       1.000000     35.000000     2.000000     2.000000    79.000000
# max       1.000000     70.000000     9.000000     9.000000    97.000000
#
#           ...             XNorm        YNorm     XNormAdj     YNormAdj  \
# count     ...       5222.000000  5222.000000  5222.000000  5222.000000
# mean      ...         76.662581    -2.464764    23.337419    11.243010
# std       ...          8.663355    13.260413     8.663355     8.773563
# min       ...         26.000000   -41.000000     3.000000     1.000000
# 25%       ...         73.000000   -10.000000    18.000000     5.000000
# 50%       ...         79.000000    -2.000000    21.000000     9.000000
# 75%       ...         82.000000     5.000000    27.000000    15.000000
# max       ...         97.000000    39.000000    74.000000    42.000000
#
#                lnX          lnY       dscore       pgoalx       pgoaly  \
# count  5222.000000  5222.000000  5222.000000  5222.000000  5222.000000
# mean      3.093281     2.103069     0.121026     0.098238     0.098238
# std       0.328092     0.844278     1.524210     0.024967     0.062573
# min       1.098612     0.000000    -8.000000     0.035279     0.025408
# 25%       2.890372     1.609438    -1.000000     0.081191     0.054491
# 50%       3.044522     2.197225     0.000000     0.099181     0.078701
# 75%       3.295837     2.708050     1.000000     0.111901     0.118441
# max       4.304065     3.737670     8.000000     0.376709     0.317063
#
#              pgoal
# count  5222.000000
# mean      0.098238
# std       0.067331
# min       0.007063
# 25%       0.048466
# 50%       0.084774
# 75%       0.128011
# max       0.456401
#
# [8 rows x 21 columns]

# %%
dw.groupby(['period'])[['isgoal', 'pgoal']].sum()
# Out:
#         isgoal       pgoal
# period
# 1        162.0  165.466699
# 2        171.0  174.011598
# 3        171.0  163.395613
# 4          9.0   10.126091

# %%
dw.groupby(['dscore'])[['isgoal', 'pgoal']].sum()
# Out:
#         isgoal       pgoal
# dscore
# -8         0.0    0.204364
# -7         1.0    0.160190
# -6         2.0    0.886353
# -5         2.0    1.134979
# -4         5.0    5.614352
# -3        19.0   15.529323
# -2        34.0   36.600620
# -1        87.0   86.362399
#  0       186.0  192.507010
#  1       107.0   96.971437
#  2        45.0   49.340075
#  3        18.0   18.159240
#  4         3.0    4.926142
#  5         3.0    2.612319
#  6         1.0    1.521603
#  7         0.0    0.435306
#  8         0.0    0.034289

# %%
dw.groupby(['teamcode'])[['isgoal', 'pgoal']].sum()
# Out:
#           isgoal      pgoal
# teamcode
# ANA         21.0  18.653223
# BOS         15.0  15.483934
# BUF         19.0  20.347039
# CAR         17.0  19.254251
# CBJ         20.0  16.163409
# CGY         20.0  17.201594
# CHI         21.0  15.596250
# COL         16.0  15.062551
# DAL         15.0  17.065324
# DET         13.0  17.346203
# EDM         20.0  20.294310
# FLA         19.0  16.328468
# LA          11.0  11.890076
# MIN         15.0  18.671528
# MTL         15.0  17.323671
# NJ          16.0  13.913586
# NSH         20.0  17.127156
# NYI         24.0  17.388109
# NYR         14.0  14.615696
# OTT         15.0  19.139237
# PHI         15.0  15.570242
# PHX         11.0  15.930434
# PIT         30.0  18.451884
# SJ          13.0  17.102264
# STL          9.0  15.784915
# TB          22.0  18.416858
# TOR         14.0  18.649882
# VAN         20.0  20.405167
# WPG         16.0  16.437401
# WSH         17.0  17.385338

# %%
dw.groupby(['oteamcode'])[['isgoal', 'pgoal']].sum()
# Out:
#            isgoal       pgoal
# oteamcode
# 1           220.0  238.467979
# ANA          12.0   10.235956
# BOS           9.0    7.528176
# BUF          11.0   10.855427
# CAR          12.0    9.678495
# CBJ          13.0    8.015068
# CGY          10.0    8.725645
# CHI          11.0    8.087450
# COL          12.0    9.209972
# DAL           8.0    9.589179
# DET           8.0   10.366207
# EDM          11.0   11.965575
# FLA          12.0    9.893618
# LA            8.0    6.473614
# MIN           9.0   11.567418
# MTL           9.0    8.459519
# NJ            8.0    6.779543
# NSH           6.0    7.839689
# NYI          19.0    9.676932
# NYR           9.0    7.298342
# OTT           6.0   10.458967
# PHI           7.0    6.412220
# PHX           4.0    7.754979
# PIT          16.0    9.702288
# SJ            7.0    7.938603
# STL           7.0    8.966579
# TB           10.0   10.669622
# TOR           7.0   10.894709
# VAN          11.0   11.573524
# WPG          12.0    9.314223
# WSH           9.0    8.600480

# %%
dz = dm[dm['shotType']=='Slap']

# %%
dh = dz[dz['eventtype']=='GOAL']

plt.hist2d(dh['XNormAdj'], dh['YNorm'],bins=30)
plt.show()

# %%
n1 = sm.Logit(dz['isgoal'], sm.add_constant(dz['lnX'])).fit()
print (n1.get_margeff(method='dydx', at='overall').summary())

# Generate predicted values and predict results
dz.ix[:, 'pgoalx'] = n1.predict()
dz.plot(kind='scatter',x='XNormAdj', y='pgoalx')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.188123
#          Iterations 7
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# lnX           -0.0633      0.006    -11.380      0.000        -0.074    -0.052
# ==============================================================================
# C:\Programs\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_margins.py:522: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   exog_names.pop(const_idx)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
n2 = sm.Logit(dz['isgoal'], sm.add_constant(dz['lnY'])).fit()
print (n2.get_margeff(method='dydx', at='overall').summary())
# Generate predicted values and predict results
dz.ix[:, 'pgoaly'] = n2.predict()
dz.plot(kind='scatter', x='YNormAdj', y='pgoaly')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.189648
#          Iterations 7
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# lnY           -0.0222      0.002     -9.822      0.000        -0.027    -0.018
# ==============================================================================
# C:\Programs\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_margins.py:522: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   exog_names.pop(const_idx)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
n3 = sm.Logit(dz['isgoal'], sm.add_constant(dz[['lnX', 'lnY']])).fit()
print (n3.get_margeff(method='dydx', at='overall').summary())
dz.ix[:, 'pgoal'] = n3.predict()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.185000
#          Iterations 7
#         Logit Marginal Effects
# =====================================
# Dep. Variable:                 isgoal
# Method:                          dydx
# At:                           overall
# ==============================================================================
#                 dy/dx    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# lnX           -0.0567      0.005    -10.386      0.000        -0.067    -0.046
# lnY           -0.0194      0.002     -8.604      0.000        -0.024    -0.015
# ==============================================================================
# C:\Programs\Anaconda3\lib\site-packages\statsmodels\discrete\discrete_margins.py:522: VisibleDeprecationWarning: converting an array with ndim > 0 to an index will result in an error in the future
#   exog_names.pop(const_idx)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:288: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Programs\Anaconda3\lib\site-packages\pandas\core\indexing.py:465: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
dz.groupby(['period'])[['isgoal', 'pgoal']].sum()
# Out:
#         isgoal       pgoal
# period
# 1        158.0  170.148584
# 2        198.0  183.234769
# 3        178.0  178.411389
# 4         11.0   13.205258

# %%
dz.groupby(['dscore'])[['isgoal', 'pgoal']].sum()
# Out:
#         isgoal       pgoal
# dscore
# -9         0.0    0.040077
# -8         0.0    0.092071
# -7         1.0    0.123923
# -6         1.0    0.448073
# -5         1.0    1.749435
# -4        10.0    7.355973
# -3        17.0   13.792973
# -2        53.0   38.408413
# -1        99.0   91.762175
#  0       195.0  201.654269
#  1        84.0  107.435309
#  2        49.0   53.380836
#  3        23.0   18.281427
#  4         9.0    6.425306
#  5         2.0    2.593277
#  6         1.0    0.927900
#  7         0.0    0.262677
#  8         0.0    0.207495
#  9         0.0    0.058391

# %%
dz.groupby(['teamcode'])[['isgoal', 'pgoal']].sum()
# Out:
#           isgoal      pgoal
# teamcode
# ANA         27.0  16.989277
# BOS         18.0  16.355484
# BUF         21.0  21.230236
# CAR         15.0  18.615548
# CBJ         22.0  20.259693
# CGY         25.0  17.737793
# CHI         19.0  21.226418
# COL         17.0  17.259665
# DAL         23.0  20.282393
# DET         17.0  15.435766
# EDM         23.0  19.604427
# FLA         20.0  23.343828
# LA          12.0  17.167310
# MIN         18.0  17.558686
# MTL         19.0  16.150497
# NJ          18.0  17.514035
# NSH         17.0  19.617930
# NYI         26.0  15.816940
# NYR         20.0  19.319796
# OTT         12.0  18.094726
# PHI         12.0  15.413536
# PHX         17.0  19.943523
# PIT          7.0  12.120803
# SJ          26.0  23.683800
# STL         10.0  14.958971
# TB          21.0  16.587322
# TOR         16.0  16.613345
# VAN         17.0  20.774277
# WPG         17.0  20.392398
# WSH         13.0  14.931575

# %%
dz.groupby(['oteamcode'])[['isgoal', 'pgoal']].sum()
# Out:
#            isgoal       pgoal
# oteamcode
# 1           252.0  261.238963
# ANA          16.0    8.158821
# BOS          13.0    9.890553
# BUF           6.0   10.219623
# CAR          10.0   10.665697
# CBJ           8.0   11.158661
# CGY          15.0    9.542436
# CHI          12.0    9.597971
# COL           9.0    9.523296
# DAL          11.0   10.177815
# DET          11.0    8.591988
# EDM          12.0   11.126607
# FLA          10.0    9.131087
# LA            6.0    9.555355
# MIN          14.0    9.576373
# MTL          13.0    9.922431
# NJ            7.0    8.931422
# NSH           7.0    9.948937
# NYI          10.0    8.876526
# NYR           8.0    9.067525
# OTT           4.0    9.118912
# PHI           7.0    9.073168
# PHX           8.0   10.829859
# PIT           3.0    7.123643
# SJ           13.0    8.996740
# STL           5.0    7.303898
# TB           15.0   10.375043
# TOR          12.0    9.572761
# VAN           6.0    9.172029
# WPG          15.0   10.057069
# WSH           7.0    8.474790
